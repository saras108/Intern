# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Implement Logistic Regression

# %% [markdown]
# This will be helpful to further familiarize yourself with Numpy and how Logistic Regression actually works.
# If you face any problems, feel free to contact us in Slack

# %% [markdown]
# ### Load the breast cancer dataset (from sklearn)

# %%
# Code here
from sklearn.datasets import load_breast_cancer
datas = load_breast_cancer()
df = pd.DataFrame(data = datas.data)

df.columns = datas.feature_names
df['target'] = datas.target

# %% [markdown]
# ### Train test split

# %%
# Code here

from sklearn.model_selection import train_test_split
X = df.drop('target' , axis = 1)
y = df['target']
X_train , X_test , y_train ,  y_test = train_test_split(X , y , test_size = 0.3 , random_state = 42)

# %% [markdown]
# ### Apply feature scaling on the data

# %%
# Code here


""" Min-max Normalization using sklearn """

from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()


""" Standard Normalization  using sklearn""" 

# from sklearn.preprocessing import StandardScaler
# scalar = StandardScaler()


"""  datasets normalization while using sklearn""" 

X_train = scalar.fit_transform(X_train)
X_test = scalar.fit_transform(X_test)

# %%
sample, featue =  X_train.shape

# %% [markdown]
# ### Define the Parameters (W or Θ) here
# Create an appropriate shape numpy array for W

# %%
W = np.random.rand(featue)  # Weights
alpha = 0.01 # Learning Rate
W.shape
# Out:
# (30,)

# %% [markdown]
# ### Define sigmoid and its derivative
# ![image.png](attachment:image.png)

# %%
def sigmoid(X: np.array):
    # Apply sigmoid to X and return 
    z = 1/(1+np.exp(-X))
    return z

def sigmoid_(X: np.array):
    # return derivative of sigmoid
    z = sigmoid(X)
    dz = z*(1-z)
    return dz

# %% [markdown]
# ### Prediction methods

# %%
def predict_prob(X, W):
    # Return the class probabilities here
    y  = X.dot(W)
    z = sigmoid(y)
    return z

# %% [markdown]
# ### Define the Cross entropy loss function
#
# ![image.png](attachment:image.png)

# %%
# Code here
def binary_cross_entropy(y, yhat):
    n  = y.shape[0]
    first_exp = np.sum(y.dot(np.log(yhat)))
    second_exp = np.sum((1-y).dot(np.log(1-yhat)))
    expression = -(first_exp + second_exp)/n
    return expression

# %%
yhat = predict_prob(X_train, W)
# yhat

# %%
loss = binary_cross_entropy(y_train, yhat)
print(loss)
# Out:
# 2.1573145809709393

# %% [markdown]
# # Solve using Gradient Descent

# %% [markdown]
# ### Calculate gradient
# For practice, you can try to derive the gradient using pen and paper

# %%
def compute_gradient(X, y, yhat, W):
    dw = X.T.dot (np.subtract(yhat , y))/sample
    
    return dw

# %% [markdown]
# ### Update Weights

# %%
# Code here
W = W - alpha*compute_gradient(X_train, y_train, yhat ,  W)

# W.shape
W
# Out:
# array([0.02370124, 0.32219219, 0.36679601, 0.9767634 , 0.72138369,
#        0.48943015, 0.70185331, 0.92397957, 0.90785974, 0.40874635,
#        0.59465823, 0.90806266, 0.79987728, 0.11189189, 0.41307535,
#        0.87370827, 0.87740436, 0.33365979, 0.85629621, 0.14076173,
#        0.16022886, 0.94011625, 0.68143597, 0.65444204, 0.4066014 ,
#        0.6896424 , 0.41611365, 0.31143508, 0.55638788, 0.72411238])

# %% [markdown]
# ### Repeat for N- Iterations

# %%
N = 1000
losses = []
    
for i in range(N):
    # Predict
    yhat = predict_prob(X_train, W)
    
    
    # Calculate Loss
    loss = binary_cross_entropy(y_train, yhat)
    
    # Compute gradient dL/dW
    dW = compute_gradient(X_train, y_train, yhat, W)
    
    # Update the weights
    W = W - alpha*dW
    
    losses.append(loss)

# %%
losses
# Out:
# [2.1523567170238933,
#  2.1474019534755717,
#  2.142450311240966,
#  2.137501811369248,
#  2.132556475044433,
#  2.1276143235858953,
#  2.1226753784491734,
#  2.1177396612265764,
#  2.1128071936478237,
#  2.1078779975807445,
#  2.1029520950318434,
#  2.0980295081470723,
#  2.093110259212369,
#  2.0881943706544166,
#  2.083281865041165,
#  2.078372765082592,
#  2.0734670936312662,
#  2.0685648736830125,
#  2.063666128377551,
#  2.0587708809991523,
#  2.053879154977198,
#  2.048990973886882,
#  2.0441063614498303,
#  2.039225341534643,
#  2.034347938157624,
#  2.029474175483304,
#  2.0246040778251264,
#  2.019737669645966,
#  2.0148749755588042,
#  2.010016020327325,
#  2.0051608288664338,
#  2.0003094262429375,
#  1.9954618376760704,
#  1.9906180885381077,
#  1.9857782043549057,
#  1.9809422108065018,
#  1.976110133727634,
#  1.9712819991083668,
#  1.9664578330945475,
#  1.961637661988466,
#  1.9568215122492585,
#  1.952009410493571,
#  1.9472013834959967,
#  1.9423974581896093,
#  1.9375976616664972,
#  1.9328020211782544,
#  1.9280105641364558,
#  1.9232233181131753,
#  1.9184403108414403,
#  1.91366157021571,
#  1.9088871242923466,
#  1.9041170012900377,
#  1.899351229590275,
#  1.8945898377377783,
#  1.889832854440874,
#  1.8850803085719898,
#  1.8803322291679936,
#  1.875588645430616,
#  1.870849586726806,
#  1.8661150825891377,
#  1.8613851627161433,
#  1.8566598569726533,
#  1.851939195390174,
#  1.8472232081671562,
#  1.8425119256693425,
#  1.8378053784300572,
#  1.8331035971504819,
#  1.8284066126999239,
#  1.8237144561160856,
#  1.8190271586053017,
#  1.8143447515427646,
#  1.8096672664727413,
#  1.804994735108748,
#  1.8003271893337796,
#  1.7956646612004241,
#  1.7910071829310454,
#  1.7863547869179095,
#  1.7817075057232836,
#  1.7770653720795535,
#  1.772428418889298,
#  1.7677966792253514,
#  1.7631701863308349,
#  1.7585489736192028,
#  1.75393307467424,
#  1.7493225232500362,
#  1.7447173532709566,
#  1.7401175988316033,
#  1.7355232941967127,
#  1.7309344738010737,
#  1.7263511722494007,
#  1.7217734243162024,
#  1.7172012649456094,
#  1.712634729251182,
#  1.7080738525157024,
#  1.7035186701909553,
#  1.6989692178974334,
#  1.6944255314240897,
#  1.6898876467280033,
#  1.6853555999340468,
#  1.6808294273345383,
#  1.6763091653888333,
#  1.671794850722916,
#  1.6672865201289597,
#  1.6627842105648551,
#  1.65828795915369,
#  1.6537978031832492,
#  1.6493137801054223,
#  1.6448359275356412,
#  1.640364283252247,
#  1.635898885195831,
#  1.6314397714685573,
#  1.62698698033346,
#  1.6225405502136632,
#  1.6181005196916276,
#  1.613666927508319,
#  1.6092398125623657,
#  1.6048192139091662,
#  1.6004051707599705,
#  1.5959977224809292,
#  1.5915969085920918,
#  1.5872027687663852,
#  1.5828153428285372,
#  1.5784346707539767,
#  1.5740607926676884,
#  0.6017782146687066,
#  0.6016783944197897,
#  0.6015788653968007,
#  0.601479624846112,
#  0.6013806700436888,
#  0.6012819982947719,
#  0.6011836069335604,
#  0.6010854933229007,
#  0.6009876548539771,
#  0.6008900889460062,
#  0.6007927930459349,
#  0.6006957646281406,
#  0.6005990011941353,
#  0.6005025002722727,
#  0.6004062594174588,
#  0.6003102762108641,
#  0.6002145482596403,
#  0.6001190731966402,
#  0.6000238486801389,
#  0.5999288723935597,
#  0.5998341420452016,
#  0.5997396553679708,
#  0.599645410119114,
#  0.5995514040799554,
#  0.5994576350556365,
#  0.5993641008748571,
#  0.5992707993896218,
#  0.5991777284749862,
#  0.5990848860288087,
#  0.5989922699715021,
#  0.5988998782457906,
#  0.5988077088164673,
#  0.5987157596701546,
#  0.598624028815069,
#  0.5985325142807861,
#  0.5984412141180088,
#  0.5983501263983386,
#  0.5982592492140494,
#  0.5981685806778625,
#  0.5980781189227251,
#  0.5979878621015913,
#  0.597897808387204,
#  0.5978079559718815,
#  0.597718303067304,
#  0.5976288479043036,
#  0.5975395887326571,
#  0.5974505238208793,
#  0.5973616514560204,
#  0.5972729699434642,
#  0.5971844776067294,
#  0.5970961727872722,
#  0.5970080538442919,
#  0.5969201191545377,
#  0.5968323671121184,
#  0.5967447961283138,
#  0.5966574046313875,
#  0.5965701910664036,
#  0.5964831538950426,
#  0.5963962915954218,
#  0.5963096026619167,
#  0.5962230856049834,
#  0.5961367389509847,
#  0.5960505612420168,
#  0.595964551035738,
#  0.5958787069052002,
#  0.5957930274386803,
#  0.5957075112395164,
#  0.5956221569259421,
#  0.5955369631309261,
#  0.5954519285020108,
#  0.5953670517011544,
#  0.5952823314045742,
#  0.5951977663025907,
#  0.5951133550994755,
#  0.5950290965132979,
#  0.5949449892757767,
#  0.5948610321321296,
#  0.5947772238409282,
#  0.5946935631739517,
#  0.5946100489160433,
#  0.5945266798649687,
#  0.5944434548312746,
#  0.5943603726381497,
#  0.5942774321212884,
#  0.5941946321287531,
#  0.5941119715208407,
#  0.5940294491699489,
#  0.5939470639604449,
#  0.5938648147885348,
#  0.5937827005621353,
#  0.5937007202007455,
#  0.5936188726353219,
#  0.5935371568081522,
#  0.5934555716727339,
#  0.5933741161936508,
#  0.5932927893464532,
#  0.5932115901175379,
#  0.5931305175040309,
#  0.5930495705136701,
#  0.5929687481646904,
#  0.5928880494857085,
#  0.592807473515611,
#  0.5927270193034421,
#  0.5926466859082931,
#  0.5925664723991935,
#  0.592486377855002,
#  0.5924064013643008,
#  0.5923265420252882,
#  0.5922467989456758,
#  0.5921671712425837,
#  0.5920876580424382,
#  0.592008258480872,
#  0.5919289717026217,
#  0.5918497968614308,
#  0.5917707331199507,
#  0.591691779649644,
#  0.5916129356306893,
#  0.5915342002518852,
#  0.5914555727105573,
#  0.5913770522124656,
#  0.5912986379717124,
#  0.5912203292106519,
#  0.5911421251598,
#  0.5910640250577459,
#  0.5909860281510646,
#  0.5909081336942293,
#  0.5908303409495264,
#  0.5907526491869698,
#  0.5906750576842172,
#  0.5905975657264877,
#  0.5905201726064779,
#  0.5904428776242827,
#  0.5903656800873134,
#  0.5902885793102186,
#  0.5902115746148058,
#  0.5901346653299634,
#  0.5900578507915839,
#  0.5899811303424874,
#  0.5899045033323472,
#  0.5898279691176143,
#  0.5897515270614441,
#  0.5896751765336244,
#  0.5895989169105023,
#  0.5895227475749134,
#  0.5894466679161114,
#  0.5893706773296983,
#  0.5892947752175554,
#  0.589218960987775,
#  0.5891432340545939,
#  0.5890675938383254,
#  0.588992039765294,
#  0.5889165712677702,
#  0.5888411877839057,
#  0.58876588875767,
#  0.5886906736387867,
#  0.5886155418826715,
#  0.58854049295037,
#  0.5884655263084977,
#  0.588390641429178,
#  0.5883158377899834,
#  0.588241114873877,
#  0.5881664721691523,
#  0.5880919091693771,
#  0.5880174253733353,
#  0.5879430202849709,
#  0.5878686934133315,
#  0.5877944442725135,
#  0.5877202723816075,
#  0.5876461772646433,
#  0.5875721584505373,
#  0.5874982154730388,
#  0.5874243478706789,
#  0.5873505551867167,
#  0.5872768369690903,
#  0.587203192770364,
#  0.5871296221476799,
#  0.5870561246627076,
#  0.5869826998815951,
#  0.5869093473749204,
#  0.5868360667176437,
#  0.5867628574890599,
#  0.5866897192727516,
#  0.5866166516565425,
#  0.5865436542324524,
#  0.5864707265966501,
#  0.5863978683494109,
#  0.5863250790950697,
#  0.586252358441979,
#  0.5861797060024639,
#  0.5861071213927809,
#  0.5860346042330736,
#  0.5859621541473321,
#  0.5858897707633502,
#  0.5858174537126857,
#  0.5857452026306182,
#  0.58567301715611,
#  0.5856008969317658,
#  0.5855288416037937,
#  0.5854568508219655,
#  0.5853849242395794,
#  0.5853130615134212,
#  0.5852412623037262,
#  0.585169526274143,
#  0.5850978530916958,
#  0.5850262424267487,
#  0.5849546939529688,
#  0.5848832073472914,
#  0.584811782289884,
#  0.584740418464112,
#  0.5846691155565041,
#  0.5845978732567177,
#  0.584526691257506,
#  0.5844555692546838,
#  0.5843845069470948,
#  0.5843135040365792,
#  0.5842425602279414,
#  0.5841716752289173,
#  0.5841008487501438]

# %% [markdown]
# ### Plot the loss curve

# %%
# Loss curve here

import matplotlib.pyplot as plt

plt.plot(losses)

# %% [markdown]
# ### Calculate the classification report and the confusion matrix

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Scores here

print(classification_report(y_train, yhat, target_names=['target']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9753a6cdea7e> in <module>
#       1 # Scores here
#       2
# ----> 3 print(classification_report(y_train, yhat, target_names=target))
#
# NameError: name 'target' is not defined

# %% [markdown]
# # BONUS: Create a LogisticRegression Class [OPTIONAL]
# Create a Sklearn-like API

# %%
class LogisticRegression:
    # You can define additional functions as per your need
    def __init__(self, alpha=0.001, n_iter=1000):
        self.W = None
        self.alpha = alpha
        self.n_iter = n_iter
        ...

    def fit(self, X, y):
        pass

    def predict(self, X):
        pass

# %%
model = LogisticRegression()
model.fit(X, y)
predictions = model.predict(X)

# %% [markdown]
# ### Compare metrics with Sklearn's implementation

# %%
from sklearn.linear_model import LogisticRegression as SKLogisticRegression

# %%
sklearn_model = SKLogisticRegression()
sklearn_model.fit(X, y)
sklearn_predictions = sklearn_model.predict(X)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
### compare classification report and confusion matrix here
